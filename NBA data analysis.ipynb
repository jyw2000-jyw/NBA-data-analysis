# %% [markdown]
# # In this project:
#
# use existing data set
#
# Data Source: https://www.kaggle.com/fivethirtyeight/fivethirtyeight-nba-elo-dataset/
#
# The data set in this project is based on Complete History Of The NBA.
#
# In the data file nbaallelo.csv are the following variables:

# %% [markdown]
# Header | Definition
# ---|---------
# `gameorder` | Play order of game in NBA history
# `game_id` | Unique ID for each game
# `lg_id` | Which league the game was played in
# `_iscopy` | Each row of data is tied to a single team for a single game, so _iscopy flags if this game_id has already occured for the opposing team in the same matchup
# `year_id` | Season id, named based on year in which the season ended
# `date_game` | Game date
# `is_playoffs` | Flag for playoff games
# `team_id` | Three letter code for team name, from Basketball Reference
# `fran_id` | Franchise id. Multiple team_ids can fall under the same fran_id due to name changes or moves. Interactive is grouped by fran_id.
# `pts` | Points scored by team
# `elo_i` | Team elo entering the game
# `elo_n` | Team elo following the game
# `win_equiv` | Equivalent number of wins in a 82-game season for a team of elo_n quality
# `opp_id` | Team id of opponent
# `opp_fran` | Franchise id of opponent
# `opp_pts` | Points scored by opponent
# `opp_elo_i` | Opponent elo entering the game
# `opp_elo_n` | Opponent elo following the game
# `game_location` | Home (H), away (A), or neutral (N)
# `game_result` | Win or loss for team in the team_id column
# `forecast` | Elo-based chances of winning for the team in the team_id column, based on elo ratings and game location
# `notes` | Additional information

# %%
import pandas as pd
nba = pd.read_csv('nbaallelo.csv')
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
pd.set_option('display.max.columns',None)   # None表示全部列展示，设置数字多少就显示多少列。
pd.set_option('display.precision',2)      # 设置精度为两位小数
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Examining the NBA data

# %%
len(nba) # 查看数据长度
# Out:
# 126314

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null object
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null object
# game_result      126314 non-null object
# ...

# %%
nba.describe()   # 对数据集进行简单的分析（是object类型的列，不会显示）
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
# object 类型显示：
import numpy as np
nba.describe(include=[np.object])
# Out:
#              game_id   lg_id date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314    126314  126314  126314  126314   126314
# unique         63157       2     12426     104      53     104       53
# top     198504180DAL     NBA  1/2/2009     BOS  Lakers     BOS   Lakers
# freq               2  118016        30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                H           L  at New York NY
# freq           63138       63157             440

# %%
nba['team_id']
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
# 5         WSC
# 6         BOS
# 7         PRO
# 8         PIT
# 9         STB
# 10        TRH
# 11        CLR
# 12        PIT
# 13        WSC
# 14        BOS
# 15        CHS
# 16        STB
# 17        DTF
# 18        PIT
# 19        PHW
# 20        PRO
# 21        CHS
# 22        STB
# 23        NYK
# 24        TRH
# 25        DTF
# 26        TRH
# 27        CHS
# 28        BOS
# 29        DTF
#          ...
# 126284    GSW
# 126285    HOU
# 126286    ATL
# 126287    CLE
# 126288    GSW
# 126289    HOU
# 126290    ATL
# 126291    CLE
# 126292    GSW
# 126293    HOU
# 126294    CLE
# 126295    ATL
# 126296    GSW
# 126297    HOU
# 126298    CLE
# 126299    ATL
# 126300    HOU
# 126301    GSW
# 126302    CLE
# 126303    GSW
# 126304    CLE
# 126305    GSW
# 126306    GSW
# 126307    CLE
# 126308    GSW
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# ...

# %%
nba['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# CHI    4307
# PHO    4080
# ATL    4035
# MIL    4034
# POR    3870
# HOU    3820
# CLE    3810
# GSW    3701
# SEA    3547
# SAS    3515
# IND    3364
# DEN    3312
# UTA    3145
# DAL    3013
# NJN    2939
# LAC    2563
# SAC    2488
# MIA    2371
# ORL    2207
# MIN    2131
# WSB    1992
# TOR    1634
# WAS    1475
# CIN    1230
# MEM    1197
#        ...
# OAK     172
# PTC     168
# NOP     168
# PRO     168
# MMT     168
# NOK     164
# HSM     159
# TRI     135
# WSA      91
# TEX      89
# MMS      89
# CAP      89
# MNM      88
# MNP      85
# NYN      82
# CHO      82
# CHP      80
# CHZ      80
# ANA      78
# NJA      78
# AND      72
# SHE      65
# CLR      63
# WAT      62
# DNN      62
# TRH      60
# INJ      60
# DTF      60
# PIT      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
nba['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
nba[nba['fran_id']=='Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# 1193          597  194811140ROC   NBA        1     1949  11/14/1948
# 1202          602  194811170LAL   NBA        0     1949  11/17/1948
# 1217          609  194811190CHS   NBA        1     1949  11/19/1948
# 1229          615  194811210LAL   NBA        0     1949  11/21/1948
# 1234          618  194811230INJ   NBA        1     1949  11/23/1948
# 1241          621  194811240LAL   NBA        0     1949  11/24/1948
# 1256          629  194811270STB   NBA        1     1949  11/27/1948
# 1263          632  194811280LAL   NBA        0     1949  11/28/1948
# ...

# %%
nba[nba['fran_id']=='Lakers']['team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
nba[nba['team_id']=='MNL']['date_game']
# Out:
# 1136     11/4/1948
# 1152     11/6/1948
# 1159     11/9/1948
# 1170    11/11/1948
# 1183    11/13/1948
# 1193    11/14/1948
# 1202    11/17/1948
# 1217    11/19/1948
# 1229    11/21/1948
# 1234    11/23/1948
# 1241    11/24/1948
# 1256    11/27/1948
# 1263    11/28/1948
# 1264    11/30/1948
# 1272     12/1/1948
# 1286     12/4/1948
# 1301     12/5/1948
# 1310     12/8/1948
# 1323    12/10/1948
# 1333    12/12/1948
# 1347    12/15/1948
# 1373    12/19/1948
# 1377    12/21/1948
# 1378    12/22/1948
# 1403    12/26/1948
# 1410    12/29/1948
# 1427      1/1/1949
# 1450      1/5/1949
# 1471      1/8/1949
# 1479      1/9/1949
#            ...
# 9544     2/11/1960
# 9555     2/13/1960
# 9562     2/14/1960
# 9564     2/16/1960
# 9572     2/17/1960
# 9583     2/19/1960
# 9589     2/20/1960
# 9594     2/21/1960
# 9600     2/22/1960
# 9607     2/23/1960
# 9608     2/24/1960
# 9616     2/25/1960
# 9622     2/26/1960
# 9625     2/27/1960
# 9640      3/1/1960
# 9647      3/2/1960
# ...

# %%
nba[nba['team_id']=='LAL']['date_game']
# Out:
# 9730      10/19/1960
# 9739      10/22/1960
# 9744      10/24/1960
# 9747      10/25/1960
# 9756      10/28/1960
# 9764      10/29/1960
# 9770       11/2/1960
# 9778       11/5/1960
# 9782       11/6/1960
# 9786       11/9/1960
# 9799      11/12/1960
# 9813      11/15/1960
# 9828      11/19/1960
# 9839      11/20/1960
# 9841      11/22/1960
# 9847      11/23/1960
# 9850      11/24/1960
# 9857      11/25/1960
# 9867      11/26/1960
# 9870      11/27/1960
# 9873      11/28/1960
# 9877      11/29/1960
# 9890       12/1/1960
# 9893       12/2/1960
# 9903       12/4/1960
# 9905       12/5/1960
# 9915       12/7/1960
# 9931      12/10/1960
# 9934      12/12/1960
# 9946      12/14/1960
#              ...
# 125282     2/11/2015
# 125301     2/20/2015
# 125335     2/22/2015
# 125393     2/25/2015
# 125413     2/27/2015
# 125450      3/1/2015
# 125470      3/3/2015
# 125493      3/4/2015
# 125523      3/6/2015
# 125557      3/8/2015
# 125586     3/10/2015
# 125615     3/12/2015
# ...

# %% [markdown]
# # Data Clean Up
#
# Usually, you should clean your dataset before doing analysis.
#
# 1. Missing Values
#
# 2. Invalid Values
#
# 3. Inconsistent values
#
# Missing values
#
# Show how many non-null values a column contains?

# %% [markdown]
# ## Missing Values

# %%
nba.info()  # 只有notes有缺失值
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null object
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null object
# game_result      126314 non-null object
# ...

# %%
nba[nba['notes'].isnull()] # 查看空
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %%
nba[nba['notes'].notnull()] # 查看非空
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# 1089          545  194803250CHS   NBA        0     1948   3/25/1948
# 1212          607  194811190BLB   NBA        1     1949  11/19/1948
# 1213          607  194811190BLB   NBA        0     1949  11/19/1948
# 1264          633  194811300BOS   NBA        1     1949  11/30/1948
# 1265          633  194811300BOS   NBA        0     1949  11/30/1948
# 1324          663  194812100STB   NBA        0     1949  12/10/1948
# 1325          663  194812100STB   NBA        1     1949  12/10/1948
# 1334          668  194812130BLB   NBA        1     1949  12/13/1948
# ...

# %%
nba[nba['notes'].isnull()]['notes'].value_counts(dropna=False)  # dropna = False表示保留nan，默认情况下dropna是true，即默认情况下不包含nan
# Out:
# NaN    120890
# Name: notes, dtype: int64

# %%
nba['notes'].value_counts(dropna=False)
# Out:
# NaN                                                            120890
# at New York NY                                                    440
# at Philadelphia PA                                                256
# at Norfolk VA                                                     240
# at Boston MA                                                      232
# at Greensboro NC                                                  218
# at Oakland CA                                                     190
# at Hampton VA                                                     170
# at Providence RI                                                  150
# at Charlotte NC                                                   140
# at Omaha NE                                                       118
# at Hartford, CT                                                   116
# at Syracuse NY                                                    104
# ...

# %%
rows_without_missing_values = nba.dropna() # 查看行非空数据(但凡nan就删除整行)
rows_without_missing_values.head()
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 930         466  194801300BLB   NBA        1     1948  1/30/1948          28
# 931         466  194801300BLB   NBA        0     1948  1/30/1948          31
# 1084        543  194803230CHS   NBA        1     1948  3/23/1948          49
# 1085        543  194803230CHS   NBA        0     1948  3/23/1948          49
# 1088        545  194803250CHS   NBA        1     1948  3/25/1948          49
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 930             0     WSC   Capitols   71  1469.35  1454.90      47.07    BLB
# 931             0     BLB  Baltimore   95  1434.05  1448.50      46.41    WSC
# 1084            1     WSC   Capitols   70  1465.90  1461.20      47.71    CHS
# 1085            1     CHS      Stags   74  1440.72  1445.42      46.09    WSC
# 1088            1     BLB  Baltimore   75  1477.26  1484.31      50.04    CHS
#
# ...

# %%
rows_without_missing_values.shape # 行非空共5424行
# Out:
# (5424, 23)

# %%
columns_without_missing_values = nba.dropna(axis=1)  # 查看列非空数据，不写默认为行（axis=0），删除列需要设置axis=1
columns_without_missing_values.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast
# ...

# %%
columns_without_missing_values.shape # 列非空共22列
# Out:
# (126314, 22)

# %%
data_with_default_values=nba.copy()   # 复制一次初始数据集
data_with_default_values
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %%
data_with_default_values['notes'].fillna(value='no notes', inplace=True) # 填充空值
data_with_default_values['notes']
# Out:
# 0         no notes
# 1         no notes
# 2         no notes
# 3         no notes
# 4         no notes
# 5         no notes
# 6         no notes
# 7         no notes
# 8         no notes
# 9         no notes
# 10        no notes
# 11        no notes
# 12        no notes
# 13        no notes
# 14        no notes
# 15        no notes
# 16        no notes
# 17        no notes
# 18        no notes
# 19        no notes
# 20        no notes
# 21        no notes
# 22        no notes
# 23        no notes
# 24        no notes
# 25        no notes
# 26        no notes
# 27        no notes
# 28        no notes
# 29        no notes
#             ...
# 126284    no notes
# 126285    no notes
# 126286    no notes
# 126287    no notes
# 126288    no notes
# 126289    no notes
# 126290    no notes
# 126291    no notes
# 126292    no notes
# 126293    no notes
# 126294    no notes
# 126295    no notes
# 126296    no notes
# 126297    no notes
# 126298    no notes
# 126299    no notes
# ...

# %%
data_with_default_values['notes'].describe()
# Out:
# count       126314
# unique         232
# top       no notes
# freq        120890
# Name: notes, dtype: object

# %%
data_with_default_values
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 10              6  194611030CLR   NBA        1     1947  11/3/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 12              7  194611040PIT   NBA        0     1947  11/4/1946
# ...

# %% [markdown]
# ## Invalid values (outliers)

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
nba[nba['pts']==0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 26684           7            0     DNR  Nuggets    0  1460.34  1457.45
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 26684      40.41    VIR  Squires        2    1484.19    1487.08             A
#
#       game_result  forecast                           notes
# 26684           L      0.33  at Richmond VA; forfeit to VIR

# %%
nba['pts'] = nba['pts'].astype(str)
nba['pts']
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: object

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs      elo_i  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06    1495.24
# std     18231.93       0.5      17.58       25.38         0.24     112.14
# min         1.00       0.0    1947.00        1.00         0.00    1091.64
# 25%     15790.00       0.0    1975.00       22.00         0.00    1417.24
# 50%     31579.00       0.5    1990.00       43.00         0.00    1500.95
# 75%     47368.00       1.0    2003.00       65.00         0.00    1576.06
# max     63157.00       1.0    2015.00      108.00         1.00    1853.10
#
#            elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n   forecast
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24      41.71     102.73    1495.24    1495.24       0.50
# std       112.46      10.63      14.81     112.14     112.46       0.22
# ...

# %%
nba['pts'].astype(float)
# Out:
# 0          66.0
# 1          68.0
# 2          63.0
# 3          47.0
# 4          33.0
#           ...
# 126309     82.0
# 126310    104.0
# 126311     91.0
# 126312     97.0
# 126313    105.0
# Name: pts, Length: 126314, dtype: float64

# %%
nba['pts']=nba['pts'].astype(float)
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %% [markdown]
# ## Inconsistent values（逻辑错误）

# %%
nba[(nba['pts']>nba['opp_pts'])&(nba['game_result']!='W')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %%
nba[(nba['pts']>nba['opp_pts'])&(nba['game_result']!='W')].empty
# Out:
# True

# %% [markdown]
# nba[(nba['pts']<nba['opp_pts'])&(nba['game_result']!='L')]

# %%
nba[(nba['pts']<nba['opp_pts'])&(nba['game_result']!='L')].empty
# Out:
# True

# %% [markdown]
# # Manipulating Columns
#
# 1. Add/Drop columns
#
# 2. Change Data Types

# %% [markdown]
# ## Add columns

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  float64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df=nba.copy()
df['lead']=df['pts']-df['opp_pts']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  float64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id   pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies  66.0  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks  68.0  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags  63.0  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks  47.0  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons  33.0  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df['lead'].max()
# Out:
# 68.0

# %%
df.rename(columns={'game_result':'result','game_location':'location'},inplace=True)    # inplace=True改变在本身而不是复制体上。
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  float64
#  11  elo_i        126314 non-null  float64
#  12  elo_n        126314 non-null  float64
#  13  win_equiv    126314 non-null  float64
#  14  opp_id       126314 non-null  object
#  15  opp_fran     126314 non-null  object
#  16  opp_pts      126314 non-null  int64
#  17  opp_elo_i    126314 non-null  float64
# ...

# %% [markdown]
# ## Drop colums

# %%
df.drop(['elo_i','elo_n'],axis=1,inplace=True)   # 删除列（设置参数为axis=1，否则默认为删除行）
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  float64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  opp_elo_i    126314 non-null  float64
#  16  opp_elo_n    126314 non-null  float64
#  17  location     126314 non-null  object
# ...

# %% [markdown]
# ## Change data type

# %% [markdown]
# ### to_datetime()

# %%
df.info()
df['date_game']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  float64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  opp_elo_i    126314 non-null  float64
#  16  opp_elo_n    126314 non-null  float64
#  17  location     126314 non-null  object
# ...

# %%
pd.to_datetime(df['date_game'])
# Out:
# 0        1946-11-01
# 1        1946-11-01
# 2        1946-11-02
# 3        1946-11-02
# 4        1946-11-02
#             ...
# 126309   2015-06-11
# 126310   2015-06-14
# 126311   2015-06-14
# 126312   2015-06-16
# 126313   2015-06-16
# Name: date_game, Length: 126314, dtype: datetime64[ns]

# %%
df['date_game']=pd.to_datetime(df['date_game'])       #适当的数据类型转化可以减小内存占用（22MB --> 21.2MB）
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  float64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  opp_elo_i    126314 non-null  float64
#  16  opp_elo_n    126314 non-null  float64
# ...

# %% [markdown]
# ### Categorical()

# %%
df['location']
# Out:
# 0         H
# 1         A
# 2         H
# 3         A
# 4         H
#          ..
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: location, Length: 126314, dtype: object

# %%
df['location'].value_counts()
# Out:
# A    63138
# H    63138
# N       38
# Name: location, dtype: int64

# %%
pd.Categorical(df['location'])
# Out:
# [H, A, H, A, H, ..., H, H, A, H, A]
# Length: 126314
# Categories (3, object): [A, H, N]

# %%
df['location']=pd.Categorical(df['location'])
df['location']
# Out:
# 0         H
# 1         A
# 2         H
# 3         A
# 4         H
#          ..
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: location, Length: 126314, dtype: category
# Categories (3, object): [A, H, N]

# %%
df.info()    # 内存占用更小了
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  float64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  opp_elo_i    126314 non-null  float64
#  16  opp_elo_n    126314 non-null  float64
# ...

# %% [markdown]
# # Data Analysis and Visualization

# %%
import pandas as pd
pd.set_option('display.max.columns',None)    # display all columns
nba = pd.read_csv('nbaallelo.csv')
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# Question 1:
#
# How many points did the Boston Celtics (BOS) score in each year?

# %%
nba[nba['team_id']=='BOS']     # Boolean mask 选取BOS的全部比赛
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 6               4  194611020PRO   NBA        1     1947   11/2/1946
# 14              8  194611050BOS   NBA        0     1947   11/5/1946
# 28             15  194611090DTF   NBA        1     1947   11/9/1946
# 40             21  194611130CHS   NBA        1     1947  11/13/1946
# 46             24  194611140STB   NBA        1     1947  11/14/1946
# ...           ...           ...   ...      ...      ...         ...
# 126141      63071  201504150MIL   NBA        1     2015   4/15/2015
# 126162      63082  201504190CLE   NBA        1     2015   4/19/2015
# 126173      63087  201504210CLE   NBA        1     2015   4/21/2015
# 126185      63093  201504230BOS   NBA        0     2015   4/23/2015
# 126205      63103  201504260BOS   NBA        0     2015   4/26/2015
#
#         seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 6                1            0     BOS  Celtics   53  1300.00  1294.85
# ...

# %%
nba[nba['team_id']=='BOS'].groupby('year_id')['pts'].describe()   #groupby分组
# Out:
#          count    mean    std   min    25%    50%     75%    max
# year_id
# 1947      60.0   60.08   9.28  43.0  53.75   58.5   67.25   82.0
# 1948      51.0   69.22  10.10  48.0  62.00   69.0   75.00   92.0
# 1949      60.0   76.55  11.33  54.0  68.00   75.0   83.25  108.0
# 1950      68.0   79.69  10.10  47.0  73.00   79.0   86.00  106.0
# 1951      71.0   84.90  10.88  54.0  78.00   84.0   93.00  112.0
# ...        ...     ...    ...   ...    ...    ...     ...    ...
# 2011      91.0   96.32  11.57  71.0  87.00   96.0  105.00  122.0
# 2012      86.0   91.30  10.30  71.0  85.25   91.0  100.00  115.0
# 2013      87.0   95.54  11.32  71.0  88.00   96.0  103.00  120.0
# 2014      82.0   96.24  10.13  77.0  89.25   96.0  102.75  120.0
# 2015      86.0  101.06  10.36  75.0  94.25  101.0  107.75  132.0
#
# [69 rows x 8 columns]

# %%
nba[nba['team_id']=='BOS'].groupby('year_id')['pts'].sum()
# Out:
# year_id
# 1947    3605
# 1948    3530
# 1949    4593
# 1950    5419
# 1951    6028
#         ...
# 2011    8765
# 2012    7852
# 2013    8312
# 2014    7892
# 2015    8691
# Name: pts, Length: 69, dtype: int64

# %%
# Visualization
nba[nba['team_id']=='BOS'].groupby('year_id')['pts'].sum().plot()

# %% [markdown]
# Question 2:
#
# How many points did the Boston Celtics (BOS) score in each game?

# %%
nba[nba['team_id']=='BOS']['pts']
# Out:
# 6          53
# 14         55
# 28         46
# 40         61
# 46         62
#          ...
# 126141    105
# 126162    100
# 126173     91
# 126185     95
# 126205     93
# Name: pts, Length: 5997, dtype: int64

# %%
nba[nba['team_id']=='BOS']['pts'].plot()

# %%
nba[nba['team_id']=='BOS']['pts'].plot(kind='hist')   # 直方图

# %% [markdown]
# Question 3
#
# Which 10 teams won the most games in 2000?

# %%
nba[(nba['year_id']==2000)&(nba['game_result']=='W')]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 85222      42612  199911020CHH   NBA        0     2000  11/2/1999           1
# 85225      42613  199911020DAL   NBA        0     2000  11/2/1999           1
# 85227      42614  199911020DEN   NBA        0     2000  11/2/1999           1
# 85228      42615  199911020HOU   NBA        1     2000  11/2/1999           1
# 85230      42616  199911020LAC   NBA        1     2000  11/2/1999           1
# ...          ...           ...   ...      ...      ...        ...         ...
# 87741      43871  200006090LAL   NBA        0     2000   6/9/2000         101
# 87742      43872  200006110IND   NBA        0     2000  6/11/2000         102
# 87745      43873  200006140IND   NBA        1     2000  6/14/2000         103
# 87747      43874  200006160IND   NBA        0     2000  6/16/2000         104
# 87748      43875  200006190LAL   NBA        0     2000  6/19/2000         105
#
# ...

# %%
nba[(nba['year_id']==2000)&(nba['game_result']=='W')]['team_id']
# Out:
# 85222    CHH
# 85225    DAL
# 85227    DEN
# 85228    MIL
# 85230    SEA
#         ...
# 87741    LAL
# 87742    IND
# 87745    LAL
# 87747    IND
# 87748    LAL
# Name: team_id, Length: 1264, dtype: object

# %%
nba[(nba['year_id']==2000)&(nba['game_result']=='W')]['team_id'].value_counts()
# Out:
# LAL    82
# IND    69
# POR    69
# NYK    59
# UTA    59
# MIA    58
# PHO    57
# PHI    54
# SAS    54
# MIN    51
# CHH    50
# SEA    47
# SAC    46
# TOR    45
# MIL    44
# DET    42
# ORL    41
# DAL    40
# BOS    35
# DEN    35
# HOU    34
# CLE    32
# NJN    31
# WAS    29
# ATL    28
# VAN    22
# GSW    19
# CHI    17
# LAC    15
# Name: team_id, dtype: int64

# %%
nba[(nba['year_id']==2000)&(nba['game_result']=='W')]['team_id'].value_counts().head(10)
# Out:
# LAL    82
# IND    69
# POR    69
# NYK    59
# UTA    59
# MIA    58
# PHO    57
# PHI    54
# SAS    54
# MIN    51
# Name: team_id, dtype: int64

# %%
nba[(nba['year_id']==2000)&(nba['game_result']=='W')]['team_id'].value_counts().head(10).plot()

# %%
nba[(nba['year_id']==2000)&(nba['game_result']=='W')]['team_id'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# Question 4
#
# How many games did the Los Angeles Lakers (LAL) win and lose in 2000?

# %%
nba[(nba['year_id']==2000)&(nba['team_id']=='LAL')]['game_result']
# Out:
# 85243    W
# 85255    W
# 85305    L
# 85313    W
# 85333    W
#         ..
# 87741    W
# 87743    L
# 87745    W
# 87746    L
# 87748    W
# Name: game_result, Length: 105, dtype: object

# %%
nba[(nba['year_id']==2000)&(nba['team_id']=='LAL')]['game_result'].value_counts()
# Out:
# W    82
# L    23
# Name: game_result, dtype: int64

# %%
nba[(nba['year_id']==2000)&(nba['team_id']=='LAL')]['game_result'].value_counts().plot(kind='pie')

# %% [markdown]
# Question 5
#
# What's the correlation between the home and away teams' points in a game?

# %%
nba[nba['game_location']=='H'][['pts','opp_pts']]
# Out:
#         pts  opp_pts
# 0        66       68
# 2        63       47
# 4        33       50
# 7        59       53
# 9        56       51
# ...     ...      ...
# 126305   93       95
# 126307   96       91
# 126309   82      103
# 126310  104       91
# 126312   97      105
#
# [63138 rows x 2 columns]

# %%
nba[nba['game_location']=='H'][['pts','opp_pts']].plot()    # 太密集

# %%
nba[nba['game_location']=='H'][['pts','opp_pts']].plot(x='pts',y='opp_pts') # 也不够清晰

# %%
nba[nba['game_location']=='H'][['pts','opp_pts']].plot(x='pts',y='opp_pts',kind='scatter') # 散点图

# %%
nba[nba['game_location']=='H'][['pts','opp_pts']].plot(x='pts',y='opp_pts',kind='scatter',s=1) # 将点的大小改为最小

# %%
% matplotlib inline #当调用matplotlib.pyplot的绘图函数plot()进行绘图的时候，或者生成一个figure画布的时候，可以直接在你的python console里面生成图像。

# %% [markdown]
# Question 6
#
# Plot the shot chart of James Harden during the 2018-19 season.

# %%
# !pip install nba_api

# %%
from nba_api.stats.static import teams
nba_teams = teams.get_teams()
print(nba_teams)
# Out:
# [{'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Atlanta', 'year_founded': 1949}, {'id': 1610612738, 'full_name': 'Boston Celtics', 'abbreviation': 'BOS', 'nickname': 'Celtics', 'city': 'Boston', 'state': 'Massachusetts', 'year_founded': 1946}, {'id': 1610612739, 'full_name': 'Cleveland Cavaliers', 'abbreviation': 'CLE', 'nickname': 'Cavaliers', 'city': 'Cleveland', 'state': 'Ohio', 'year_founded': 1970}, {'id': 1610612740, 'full_name': 'New Orleans Pelicans', 'abbreviation': 'NOP', 'nickname': 'Pelicans', 'city': 'New Orleans', 'state': 'Louisiana', 'year_founded': 2002}, {'id': 1610612741, 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI', 'nickname': 'Bulls', 'city': 'Chicago', 'state': 'Illinois', 'year_founded': 1966}, {'id': 1610612742, 'full_name': 'Dallas Mavericks', 'abbreviation': 'DAL', 'nickname': 'Mavericks', 'city': 'Dallas', 'state': 'Texas', 'year_founded': 1980}, {'id': 1610612743, 'full_name
# ...

# %%
print(nba_teams[0])
# Out:
# {'id': 1610612737, 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL', 'nickname': 'Hawks', 'city': 'Atlanta', 'state': 'Atlanta', 'year_founded': 1949}

# %%
from nba_api.stats.static import players
nba_players = players.get_players()
nba_players
# Out:
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
#  {'id': 76006,
# ...

# %%
for player in nba_players:
    if player["full_name"] == 'James Harden':
        harden = player
    if player["full_name"] == 'Yao Ming':
        yao=player
    if player['full_name'] == 'Stephen Curry':
        curry=player
print(harden)
print(yao)
print(curry)
# Out:
# {'id': 201935, 'full_name': 'James Harden', 'first_name': 'James', 'last_name': 'Harden', 'is_active': True}
# {'id': 2397, 'full_name': 'Yao Ming', 'first_name': '', 'last_name': 'Yao Ming', 'is_active': False}
# {'id': 201939, 'full_name': 'Stephen Curry', 'first_name': 'Stephen', 'last_name': 'Curry', 'is_active': True}

# %%
# James Harden
from nba_api.stats.endpoints import shotchartdetail
shot_chart = shotchartdetail.ShotChartDetail(
    team_id=0,
    player_id=harden['id'],
    season_nullable='2018-19').get_data_frames()[0]
shot_chart
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0    Shot Chart Detail  0021800009            103     201935  James Harden
# 1    Shot Chart Detail  0021800009            246     201935  James Harden
# 2    Shot Chart Detail  0021800009            282     201935  James Harden
# 3    Shot Chart Detail  0021800009            421     201935  James Harden
# 4    Shot Chart Detail  0021800009            635     201935  James Harden
# ..                 ...         ...            ...        ...           ...
# 838  Shot Chart Detail  0021801218            302     201935  James Harden
# 839  Shot Chart Detail  0021801218            321     201935  James Harden
# 840  Shot Chart Detail  0021801218            323     201935  James Harden
# 841  Shot Chart Detail  0021801218            417     201935  James Harden
# 842  Shot Chart Detail  0021801218            452     201935  James Harden
#
#         TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# ...

# %%
shot_chart.plot(x = 'LOC_X', y = 'LOC_Y', kind='scatter', s = 3)

# %%
shot_chart.plot('LOC_X','LOC_Y',kind='hexbin',colormap='gist_heat_r')

# %%
# Stephen Curry
from nba_api.stats.endpoints import shotchartdetail
shot_chart = shotchartdetail.ShotChartDetail(
    team_id=0,
    player_id=curry['id'],
    season_nullable='2018-19').get_data_frames()[0]
shot_chart
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0    Shot Chart Detail  0021800002             10     201939  Stephen Curry
# 1    Shot Chart Detail  0021800002             58     201939  Stephen Curry
# 2    Shot Chart Detail  0021800002            131     201939  Stephen Curry
# 3    Shot Chart Detail  0021800002            145     201939  Stephen Curry
# 4    Shot Chart Detail  0021800002            293     201939  Stephen Curry
# ..                 ...         ...            ...        ...            ...
# 627  Shot Chart Detail  0021801205            325     201939  Stephen Curry
# 628  Shot Chart Detail  0021801205            503     201939  Stephen Curry
# 629  Shot Chart Detail  0021801205            533     201939  Stephen Curry
# 630  Shot Chart Detail  0021801215             48     201939  Stephen Curry
# 631  Shot Chart Detail  0021801215            114     201939  Stephen Curry
#
# ...

# %%
shot_chart.plot(x = 'LOC_X', y = 'LOC_Y', kind='scatter', s = 1)

# %%
shot_chart.plot('LOC_X','LOC_Y',kind='hexbin',colormap='gist_heat_r')

# %%
# Yao Ming
import pandas as pd
from nba_api.stats.endpoints import shotchartdetail
shot_chart1 = shotchartdetail.ShotChartDetail(
    team_id=0,
    player_id=yao['id'],
    season_nullable='2010-11').get_data_frames()[0]
shot_chart1
# Out:
#             GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID PLAYER_NAME  \
# 0   Shot Chart Detail  0021000003             19       2397    Yao Ming
# 1   Shot Chart Detail  0021000003            181       2397    Yao Ming
# 2   Shot Chart Detail  0021000003            315       2397    Yao Ming
# 3   Shot Chart Detail  0021000003            495       2397    Yao Ming
# 4   Shot Chart Detail  0021000037              8       2397    Yao Ming
# 5   Shot Chart Detail  0021000037             18       2397    Yao Ming
# 6   Shot Chart Detail  0021000037             29       2397    Yao Ming
# 7   Shot Chart Detail  0021000037            213       2397    Yao Ming
# 8   Shot Chart Detail  0021000037            358       2397    Yao Ming
# 9   Shot Chart Detail  0021000037            362       2397    Yao Ming
# 10  Shot Chart Detail  0021000059              5       2397    Yao Ming
# 11  Shot Chart Detail  0021000059             66       2397    Yao Ming
# ...

# %%
print(shot_chart1.shape)    # 18组数据太少，画图效果很差
# Out:
# (18, 24)

# %%
shot_chart2 = shotchartdetail.ShotChartDetail(
    team_id=0,
    player_id=yao['id'],
    season_nullable='2008-09').get_data_frames()[0]
print(shot_chart2.shape)
# Out:
# (566, 24)

# %%
combined_chart=pd.concat([shot_chart1,shot_chart2])      # 将两个赛季数据结合
print(combined_chart.shape)
# Out:
# (584, 24)

# %%
combined_chart.plot(x = 'LOC_X', y = 'LOC_Y', kind='scatter', s = 3)

# %%
# Yao Ming 整个职业生涯投球分布
yao_season_list = []
for season in ['2003-04', '2004-05', '2005-06', '2007-08', '2008-09', '2009-10', '2010']:
    shot_chart = shotchartdetail.ShotChartDetail(
        team_id=0,
        player_id=yao['id'],
        season_nullable=season).get_data_frames()[0]
    yao_season_list.append(shot_chart)
print(len(yao_season_list))
combined_chart = pd.concat(yao_season_list)
combined_chart.shape
combined_chart.plot(x = 'LOC_X', y = 'LOC_Y', kind='scatter', s = 3)
# Out:
# 7

# %% [markdown]
# Question 7
#
# How did the score margin vary throughout the game?

# %%
from nba_api.stats.endpoints import playbyplayv2
pbp = playbyplayv2.PlayByPlayV2("0021900963").get_data_frames()[0]
pbp.info()
pbp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   GAME_ID                    455 non-null    object
#  1   EVENTNUM                   455 non-null    int64
#  2   EVENTMSGTYPE               455 non-null    int64
#  3   EVENTMSGACTIONTYPE         455 non-null    int64
#  4   PERIOD                     455 non-null    int64
#  5   WCTIMESTRING               455 non-null    object
#  6   PCTIMESTRING               455 non-null    object
#  7   HOMEDESCRIPTION            231 non-null    object
#  8   NEUTRALDESCRIPTION         0 non-null      object
#  9   VISITORDESCRIPTION         236 non-null    object
#  10  SCORE                      128 non-null    object
#  11  SCOREMARGIN                128 non-null    object
#  12  PERSON1TYPE                455 non-null    int64
# ...

# %%
pbp_copy = pbp.copy()
#pbp_copy.plot(x='WCTIMESTRING', y='SCOREMARGIN'，grid=True)    # grid网格

print(pbp_copy['SCOREMARGIN'].value_counts(dropna=False))
# Out:
# NaN    327
# -7      15
# -5      12
# -6      11
# -4      10
# -8       9
# -3       8
# 3        8
# -9       7
# 5        5
# 9        5
# 8        5
# 10       5
# -2       4
# 6        4
# -1       4
# -10      3
# 12       3
# 1        2
# TIE      2
# 4        2
# 7        2
# 2        1
# 13       1
# Name: SCOREMARGIN, dtype: int64

# %%
pbp_copy['SCOREMARGIN'].replace('TIE',0).dropna()
# Out:
# 10     -3
# 13     -6
# 14     -4
# 15     -7
# 18     -9
#        ..
# 448     9
# 449    12
# 450     9
# 453     6
# 454     6
# Name: SCOREMARGIN, Length: 128, dtype: object

# %%
pbp_copy=pbp[['WCTIMESTRING','SCOREMARGIN']].replace('TIE',0).dropna()
print(pbp_copy)
# Out:
#     WCTIMESTRING SCOREMARGIN
# 10       8:12 PM          -3
# 13       8:13 PM          -6
# 14       8:13 PM          -4
# 15       8:13 PM          -7
# 18       8:13 PM          -9
# ..           ...         ...
# 448     10:20 PM           9
# 449     10:20 PM          12
# 450     10:20 PM           9
# 453     10:21 PM           6
# 454     10:21 PM           6
#
# [128 rows x 2 columns]

# %%
pbp_copy['SCOREMARGIN']=pd.to_numeric(pbp_copy['SCOREMARGIN'])   # 转化类型成int
pbp_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 10 to 454
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WCTIMESTRING  128 non-null    object
#  1   SCOREMARGIN   128 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 3.0+ KB

# %%
pbp_copy.plot(x='WCTIMESTRING',y='SCOREMARGIN',grid=True)

# %%
pbp_copy = pbp[['WCTIMESTRING', 'SCOREMARGIN']].dropna().replace('TIE', 0)
pbp_copy['WCTIMESTRING'] = pd.to_datetime("2020-03-10" + ' ' + pbp_copy['WCTIMESTRING'])
pbp_copy['SCOREMARGIN'] = pd.to_numeric(pbp_copy['SCOREMARGIN'])
pbp_copy.info()
pbp_copy.plot(x='WCTIMESTRING', y='SCOREMARGIN', grid=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 10 to 454
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WCTIMESTRING  128 non-null    datetime64[ns]
#  1   SCOREMARGIN   128 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.0 KB

# %%
pbp_copy.plot(x='WCTIMESTRING',y='SCOREMARGIN', grid=True,figsize=(12,5))   # 调整图表大小。
